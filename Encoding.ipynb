# %%
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
df = pd.DataFrame({'Color': ['Blue','Red', 'Green', 'Blue', 'Green', 'Blue','Blue'], 'Target':[1, 0, 1, 1, 1, 0, 1]})
df
# Out:
#    Color  Target
# 0   Blue       1
# 1    Red       0
# 2  Green       1
# 3   Blue       1
# 4  Green       1
# 5   Blue       0
# 6   Blue       1

# %%
le = LabelEncoder()
df['Color'] = le.fit_transform(df['Color'])

# %%
df
# Out:
#    Color  Target
# 0      0       1
# 1      2       0
# 2      1       1
# 3      0       1
# 4      1       1
# 5      0       0
# 6      0       1

# %%
df = pd.DataFrame({'Color': ['Blue','Red', 'Green', 'Blue', 'Green', 'Blue','Blue'], 'Target':[1, 0, 1, 1, 1, 0, 1]})
df
# Out:
#    Color  Target
# 0   Blue       1
# 1    Red       0
# 2  Green       1
# 3   Blue       1
# 4  Green       1
# 5   Blue       0
# 6   Blue       1

# %%
# One Hot Encoding

df_ohe = pd.get_dummies(df['Color'], prefix = 'Color')
df_combined = pd.concat([df, df_ohe], axis=1)
df_combined
# Out:
#    Color  Target  Color_Blue  Color_Green  Color_Red
# 0   Blue       1        True        False      False
# 1    Red       0       False        False       True
# 2  Green       1       False         True      False
# 3   Blue       1        True        False      False
# 4  Green       1       False         True      False
# 5   Blue       0        True        False      False
# 6   Blue       1        True        False      False

# %%
df_ohe = pd.get_dummies(df['Color'], prefix='Color', dtype=int)
df_combined = pd.concat([df, df_ohe], axis=1)
df_combined
# Out:
#    Color  Target  Color_Blue  Color_Green  Color_Red
# 0   Blue       1           1            0          0
# 1    Red       0           0            0          1
# 2  Green       1           0            1          0
# 3   Blue       1           1            0          0
# 4  Green       1           0            1          0
# 5   Blue       0           1            0          0
# 6   Blue       1           1            0          0

# %%
# Target Encoding

mean_target = df.groupby('Color')['Target'].mean()
df['Encode_Target'] = df['Color'].map(mean_target)
df
# Out:
#    Color  Target  Encode_Target
# 0   Blue       1           0.75
# 1    Red       0           0.00
# 2  Green       1           1.00
# 3   Blue       1           0.75
# 4  Green       1           1.00
# 5   Blue       0           0.75
# 6   Blue       1           0.75
